# %%
#List into dictionary 
ls=[]
n=input("Enter the input:")
for i in range(int(n)):
    d={}
    d['Name']=input("Enter the name:")
    d['mark1']=input("Enter the Mark1:")
    d['mark2']=input("Enter the Mark2:")
    d['mark3']=input("Enter the Mark3:")
    ls.append(d)
print(ls)
# Out:
# Enter the input:3
# Enter the name:nikunj
# Enter the Mark1:45
# Enter the Mark2:75
# Enter the Mark3:96
# Enter the name:Asad
# Enter the Mark1:56
# Enter the Mark2:89
# Enter the Mark3:77
# Enter the name:Dhrumit
# Enter the Mark1:78
# Enter the Mark2:45
# Enter the Mark3:65
# [{'Name': 'nikunj', 'mark1': '45', 'mark2': '75', 'mark3': '96'}, {'Name': 'Asad', 'mark1': '56', 'mark2': '89', 'mark3': '77'}, {'Name': 'Dhrumit', 'mark1': '78', 'mark2': '45', 'mark3': '65'}]

# %%
import pandas as pd

# %%
df= pd.Series(data=ls)
df
# Out:
# 0    {'Name': 'nikunj', 'mark1': '45', 'mark2': '75...
# 1    {'Name': 'Asad', 'mark1': '56', 'mark2': '89',...
# 2    {'Name': 'Dhrumit', 'mark1': '78', 'mark2': '4...
# dtype: object

# %%
Name=['asad','dhrumit','nikunj']
Marks=[70,80,90]
ef=pd.Series(data=Marks)
ef
# Out:
# 0    70
# 1    80
# 2    90
# dtype: int64

# %%
type(ef)
# Out:
# pandas.core.series.Series

# %%
student={'name':Name, 'Mark':Marks}
student
# Out:
# {'name': ['asad', 'dhrumit', 'nikunj'], 'Mark': [70, 80, 90]}

# %%
type(student)
# Out:
# dict

# %%
de=pd.DataFrame(data=student, index=['A','B','C'])
de
# Out:
#       name  Mark
# A     asad    70
# B  dhrumit    80
# C   nikunj    90

# %%
de.shape
# Out:
# (3, 2)

# %%
de.info
# Out:
# <bound method DataFrame.info of       name  Mark
# A     asad    70
# B  dhrumit    80
# C   nikunj    90>

# %%
de.describe
# Out:
# <bound method NDFrame.describe of       name  Mark
# A     asad    70
# B  dhrumit    80
# C   nikunj    90>

# %%
#Top Five Records
#de.head()
de.head(2)
# Out:
#       name  Mark
# A     asad    70
# B  dhrumit    80

# %%
#Last Five records
de.tail()
# Out:
#       name  Mark
# A     asad    70
# B  dhrumit    80
# C   nikunj    90

# %%
de=pd.read_csv('student.csv')
de
# Out:
#        Name  Age  Marks
# 0      Asad   23     78
# 1   Dhrumit   21     89
# 2    Nikunj   22     78
# 3     karan   23     78
# 4    Jugnoo   28     78
# 5      Vraj   21     45
# 6    mitesh   23     56
# 7    Alkesh   25     58
# 8    pratik   24     45
# 9     Akash   27     42
# 10    mehak   20     45
# 11   pushpa   19     38
# 12    dehil   28     52
# 13   saloni   25     32
# 14      jay   23     28
# 15   hardik   21     53
# 16    dhruv   25     45
# 17   mishan   23     48
# 18    samir   21     42
# 19    jigar   23     99

# %%
de.shape
# Out:
# (20, 3)

# %%
de.head()
# Out:
#       Name  Age  Marks
# 0     Asad   23     78
# 1  Dhrumit   21     89
# 2   Nikunj   22     78
# 3    karan   23     78
# 4   Jugnoo   28     78

# %%
de.tail()
# Out:
#       Name  Age  Marks
# 15  hardik   21     53
# 16   dhruv   25     45
# 17  mishan   23     48
# 18   samir   21     42
# 19   jigar   23     99

# %%
type(de)
# Out:
# pandas.core.frame.DataFrame

# %%
print(de.iloc[2])
# Out:
# Name     Nikunj
# Age          22
# Marks        78
# Name: 2, dtype: object

# %%
print(de.iloc[2,2])
# Out:
# 78

# %%
de.columns
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='object')

# %%
print(de.iloc[:,0])
# Out:
# 0        Asad
# 1     Dhrumit
# 2      Nikunj
# 3       karan
# 4      Jugnoo
# 5        Vraj
# 6      mitesh
# 7      Alkesh
# 8      pratik
# 9       Akash
# 10      mehak
# 11     pushpa
# 12      dehil
# 13     saloni
# 14        jay
# 15     hardik
# 16      dhruv
# 17     mishan
# 18      samir
# 19      jigar
# Name: Name, dtype: object

# %%
de.describe
# Out:
# <bound method NDFrame.describe of        Name  Age  Marks
# 0      Asad   23     78
# 1   Dhrumit   21     89
# 2    Nikunj   22     78
# 3     karan   23     78
# 4    Jugnoo   28     78
# 5      Vraj   21     45
# 6    mitesh   23     56
# 7    Alkesh   25     58
# 8    pratik   24     45
# 9     Akash   27     42
# 10    mehak   20     45
# 11   pushpa   19     38
# 12    dehil   28     52
# 13   saloni   25     32
# 14      jay   23     28
# 15   hardik   21     53
# 16    dhruv   25     45
# 17   mishan   23     48
# 18    samir   21     42
# 19    jigar   23     99>

# %%
de.info
# Out:
# <bound method DataFrame.info of        Name  Age  Marks
# 0      Asad   23     78
# 1   Dhrumit   21     89
# 2    Nikunj   22     78
# 3     karan   23     78
# 4    Jugnoo   28     78
# 5      Vraj   21     45
# 6    mitesh   23     56
# 7    Alkesh   25     58
# 8    pratik   24     45
# 9     Akash   27     42
# 10    mehak   20     45
# 11   pushpa   19     38
# 12    dehil   28     52
# 13   saloni   25     32
# 14      jay   23     28
# 15   hardik   21     53
# 16    dhruv   25     45
# 17   mishan   23     48
# 18    samir   21     42
# 19    jigar   23     99>

# %%
# Print the values of the 2nd, 3rd, and 4th rows and the 1st and 2nd columns
print(de.iloc[1:4, 0:3])
# Out:
#       Name  Age  Marks
# 1  Dhrumit   21     89
# 2   Nikunj   22     78
# 3    karan   23     78

# %%
de.iloc[12:19]
# Out:
#       Name  Age  Marks
# 12   dehil   28     52
# 13  saloni   25     32
# 14     jay   23     28
# 15  hardik   21     53
# 16   dhruv   25     45
# 17  mishan   23     48
# 18   samir   21     42

# %%
de.head(3)
# Out:
#       Name  Age  Marks
# 0     Asad   23     78
# 1  Dhrumit   21     89
# 2   Nikunj   22     78

# %%
de.tail(3)
# Out:
#       Name  Age  Marks
# 17  mishan   23     48
# 18   samir   21     42
# 19   jigar   23     99

# %%
de[['Name','Marks']]
# Out:
#        Name  Marks
# 0      Asad     78
# 1   Dhrumit     89
# 2    Nikunj     78
# 3     karan     78
# 4    Jugnoo     78
# 5      Vraj     45
# 6    mitesh     56
# 7    Alkesh     58
# 8    pratik     45
# 9     Akash     42
# 10    mehak     45
# 11   pushpa     38
# 12    dehil     52
# 13   saloni     32
# 14      jay     28
# 15   hardik     53
# 16    dhruv     45
# 17   mishan     48
# 18    samir     42
# 19    jigar     99

# %%
de=pd.read_csv('student.csv')
de
# Out:
#        Name  Age  Marks  mark1
# 0      Asad   23     78     45
# 1   Dhrumit   21     89     46
# 2    Nikunj   22     78     47
# 3     karan   23     78     48
# 4    Jugnoo   28     78     49
# 5      Vraj   21     45     50
# 6    mitesh   23     56     51
# 7    Alkesh   25     58     52
# 8    pratik   24     45     53
# 9     Akash   27     42     54
# 10    mehak   20     45     55
# 11   pushpa   19     38     56
# 12    dehil   28     52     57
# 13   saloni   25     32     58
# 14      jay   23     28     59
# 15   hardik   21     53     60
# 16    dhruv   25     45     61
# 17   mishan   23     48     62
# 18    samir   21     42     63
# 19    jigar   23     99     64

# %%
de['total']=de['Marks']+de['mark1']
de
# Out:
#        Name  Age  Marks  mark1  total
# 0      Asad   23     78     45    123
# 1   Dhrumit   21     89     46    135
# 2    Nikunj   22     78     47    125
# 3     karan   23     78     48    126
# 4    Jugnoo   28     78     49    127
# 5      Vraj   21     45     50     95
# 6    mitesh   23     56     51    107
# 7    Alkesh   25     58     52    110
# 8    pratik   24     45     53     98
# 9     Akash   27     42     54     96
# 10    mehak   20     45     55    100
# 11   pushpa   19     38     56     94
# 12    dehil   28     52     57    109
# 13   saloni   25     32     58     90
# 14      jay   23     28     59     87
# 15   hardik   21     53     60    113
# 16    dhruv   25     45     61    106
# 17   mishan   23     48     62    110
# 18    samir   21     42     63    105
# 19    jigar   23     99     64    163

# %%
de2=de.rename(columns={'Marks':'Java','mark1':'python'})
de2
# Out:
#        Name  Age  Java  python  total
# 0      Asad   23    78      45    123
# 1   Dhrumit   21    89      46    135
# 2    Nikunj   22    78      47    125
# 3     karan   23    78      48    126
# 4    Jugnoo   28    78      49    127
# 5      Vraj   21    45      50     95
# 6    mitesh   23    56      51    107
# 7    Alkesh   25    58      52    110
# 8    pratik   24    45      53     98
# 9     Akash   27    42      54     96
# 10    mehak   20    45      55    100
# 11   pushpa   19    38      56     94
# 12    dehil   28    52      57    109
# 13   saloni   25    32      58     90
# 14      jay   23    28      59     87
# 15   hardik   21    53      60    113
# 16    dhruv   25    45      61    106
# 17   mishan   23    48      62    110
# 18    samir   21    42      63    105
# 19    jigar   23    99      64    163

# %% [markdown]
# ***Pokemon_Data***

# %%
import pandas as pd

# %%
#Data Frame using Different DataSet
df=pd.read_csv("pokemon_data.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.head(2)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary
# 0           1      False
# 1           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.tail(2)
# Out:
#        #                Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 798  720  HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721           Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 798      130     80           6       True
# 799       90     70           6       True

# %%
import pandas as pd
df= pd.read_excel('pokemon_data.csv.xlsx')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#Reading Data from Data frame
df=pd.read_csv("pokemon_data.csv")
# df['HP']
df[['HP','Attack']]
# Out:
#      HP  Attack
# 0    45      49
# 1    60      62
# 2    80      82
# 3    80     100
# 4    39      52
# ..   ..     ...
# 795  50     100
# 796  50     160
# 797  80     110
# 798  80     160
# 799  80     110
#
# [800 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name','Type 1','HP','Speed']]
# Out:
#                       Name   Type 1  HP  Speed
# 0                Bulbasaur    Grass  45     45
# 1                  Ivysaur    Grass  60     60
# 2                 Venusaur    Grass  80     80
# 3    VenusaurMega Venusaur    Grass  80     80
# 4               Charmander     Fire  39     65
# ..                     ...      ...  ..    ...
# 795                Diancie     Rock  50     50
# 796    DiancieMega Diancie     Rock  50    110
# 797    HoopaHoopa Confined  Psychic  80     70
# 798     HoopaHoopa Unbound  Psychic  80     80
# 799              Volcanion     Fire  80     70
#
# [800 rows x 4 columns]

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
#sort based on defense>50 and hp<100
# df[(df['Defense']>50) & (df['HP']<100)]
df[(df['Defense']>50 & (df['Attack']<100))]
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.iloc[5]
# Out:
# #                      5
# Name          Charmeleon
# Type 1              Fire
# Type 2               NaN
# HP                    58
# Attack                64
# Defense               58
# Sp. Atk               80
# Sp. Def               65
# Speed                 80
# Generation             1
# Legendary          False
# Name: 5, dtype: object

# %%
df.iloc[5][1]
# Out:
# 'Charmeleon'

# %%
df.sort_values(['HP','Attack'], ascending=[1,1])
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 230  213    Shuckle      Bug   Rock   20      10      230       10      230
# 381  349     Feebas    Water    NaN   20      15       20       10       55
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# ...

# %%
df['Total']=df['HP']+df['Attack']+df['Defense']+df['Generation']
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    144
# ...

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})

# %%
df = df.drop(columns=['B'])

# %%
df
# Out:
#    A  C
# 0  1  7
# 1  2  8
# 2  3  9

# %%
del df['A']

# %%
df
# Out:
#    C
# 0  7
# 1  8
# 2  9
